# %% [markdown]
# <h1>EDA</h1>

# %% [markdown]
# <h3>Importar librerias</h3>
# Como primer paso importamos las librerias que vamos a necesitar:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3>Cargar los datos</h3>
# Como cualquier EDA, necesitamos cargar los datos de nuestros csv o cualquier otro

# %%
dfHechos = pd.read_csv("./data/Hechos.csv")
dfVictimas = pd.read_csv("./data/Victimas.csv")

# %% [markdown]
# <h3>Estructura de los datos</h3>

# %% [markdown]
# Vista general del df de Hechos

# %%
dfHechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    object
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
# ...

# %%
dfHechos.head(5)
# Out:
#           ID  N_VICTIMAS      FECHA  AAAA  MM  DD     HORA HH  \
# 0  2016-0001           1   1/1/2016  2016   1   1  4:00:00  4
# 1  2016-0002           1   1/2/2016  2016   1   2  1:15:00  1
# 2  2016-0003           1   1/3/2016  2016   1   3  7:00:00  7
# 3  2016-0004           1  1/10/2016  2016   1  10  0:00:00  0
# 4  2016-0005           1  1/21/2016  2016   1  21  5:20:00  5
#
#                              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  \
# 0  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA  ...     NaN
# 1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ  ...     NaN
# 2                         AV ENTRE RIOS 2034       AVENIDA  ...  2034.0
# 3      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA  ...     NaN
# 4  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA  ...     NaN
#
#                                  Cruce  \
# 0  FERNANDEZ DE LA CRUZ, F., GRAL. AV.
# 1                  DE LOS CORRALES AV.
# ...

# %% [markdown]
# Vista general del df de Victimas

# %%
dfVictimas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID_hecho             717 non-null    object
#  1   FECHA                717 non-null    object
#  2   AAAA                 717 non-null    int64
#  3   MM                   717 non-null    int64
#  4   DD                   717 non-null    int64
#  5   ROL                  717 non-null    object
#  6   VICTIMA              717 non-null    object
#  7   SEXO                 717 non-null    object
#  8   EDAD                 717 non-null    object
#  9   FECHA_FALLECIMIENTO  717 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 56.1+ KB

# %%
dfVictimas.head(5)
# Out:
#     ID_hecho      FECHA  AAAA  MM  DD        ROL VICTIMA       SEXO EDAD  \
# 0  2016-0001   1/1/2016  2016   1   1  CONDUCTOR    MOTO  MASCULINO   19
# 1  2016-0002   1/2/2016  2016   1   2  CONDUCTOR    AUTO  MASCULINO   70
# 2  2016-0003   1/3/2016  2016   1   3  CONDUCTOR    MOTO  MASCULINO   30
# 3  2016-0004  1/10/2016  2016   1  10  CONDUCTOR    MOTO  MASCULINO   18
# 4  2016-0005  1/21/2016  2016   1  21  CONDUCTOR    MOTO  MASCULINO   29
#
#   FECHA_FALLECIMIENTO
# 0            1/1/2016
# 1            1/2/2016
# 2            1/3/2016
# 3                  SD
# 4            2/1/2016

# %% [markdown]
# <h3>Consistencia de los datos</h3>

# %% [markdown]
# <h4>DF HECHOS</h4>

# %% [markdown]
# Nulos del df de Hechos

# %%
dfHechos.isnull().sum()
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %% [markdown]
# Comprobamos que no haya duplicados

# %%
dfHechos.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hacemos un describe de las columnas numericas, para ver si podemos rescatar alguna informacion importante

# %%
dfHechos.describe()
# Out:
#        N_VICTIMAS         AAAA          MM          DD        Altura  \
# count  696.000000   696.000000  696.000000  696.000000    129.000000
# mean     1.030172  2018.188218    6.692529   15.936782   3336.635659
# std      0.179393     1.683754    3.571309    8.639646   3060.641793
# min      1.000000  2016.000000    1.000000    1.000000     30.000000
# 25%      1.000000  2017.000000    4.000000    9.000000   1359.000000
# 50%      1.000000  2018.000000    7.000000   16.000000   2551.000000
# 75%      1.000000  2020.000000   10.000000   23.000000   4500.000000
# max      3.000000  2021.000000   12.000000   31.000000  16080.000000
#
#            COMUNA
# count  696.000000
# mean     7.425287
# std      4.387050
# min      0.000000
# 25%      4.000000
# 50%      8.000000
# 75%     11.000000
# max     15.000000

# %% [markdown]
# <h4>DF VICTIMAS</h4>

# %% [markdown]
# Nulos del df de Vitimas

# %%
dfVictimas.isnull().sum()
# Out:
# ID_hecho               0
# FECHA                  0
# AAAA                   0
# MM                     0
# DD                     0
# ROL                    0
# VICTIMA                0
# SEXO                   0
# EDAD                   0
# FECHA_FALLECIMIENTO    0
# dtype: int64

# %% [markdown]
# Valores duplicados

# %%
dfVictimas.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Estadisticas descriptivas de los valores numericos

# %%
dfVictimas.describe()
# Out:
#               AAAA          MM          DD
# count   717.000000  717.000000  717.000000
# mean   2018.174338    6.688982   15.960948
# std       1.672655    3.575140    8.683358
# min    2016.000000    1.000000    1.000000
# 25%    2017.000000    4.000000    9.000000
# 50%    2018.000000    7.000000   16.000000
# 75%    2019.000000   10.000000   23.000000
# max    2021.000000   12.000000   31.000000

# %% [markdown]
# <h3>Union de los dos DF</h3>

# %% [markdown]
# Comprobamos que haya accidentes mayores a 1, ya que el df de Victimas es más grande

# %%
dfHechos[dfHechos['N_VICTIMAS'] >= 2].head(5)
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 29   2016-0041           2  3/29/2016  2016   3  29  11:00:00  11
# 97   2016-0126           2  9/18/2016  2016   9  18  22:45:00  22
# 161  2017-0026           2  2/26/2017  2017   2  26   5:15:00   5
# 170  2017-0035           3  3/23/2017  2017   3  23   5:00:00   5
# 171  2017-0036           2  3/29/2017  2017   3  29  18:00:00  18
#
#                                        LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  \
# 29                      AV DIRECTORIO Y RIVERA INDARTE       AVENIDA  ...
# 97                                IRIGOYEN Y TINOGASTA         CALLE  ...
# 161                       AV. PERITO MORENO Y FOURNIER       AVENIDA  ...
# 170  AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUC...       AVENIDA  ...
# 171                CURUPAYTI Y COLECTORA AV. GRAL. PAZ      GRAL PAZ  ...
#
#     Altura               Cruce  \
# 29     NaN  RIVERA INDARTE AV.
# 97     NaN           TINOGASTA
# ...

# %%
merged_df = pd.merge(dfHechos, dfVictimas, left_on='ID', right_on='ID_hecho', how='inner')

# %%
merged_df.columns
# Out:
# Index(['ID', 'N_VICTIMAS', 'FECHA_x', 'AAAA_x', 'MM_x', 'DD_x', 'HORA', 'HH',
#        'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'Calle', 'Altura', 'Cruce',
#        'Dirección Normalizada', 'COMUNA', 'XY (CABA)', 'pos x', 'pos y',
#        'PARTICIPANTES', 'VICTIMA_x', 'ACUSADO', 'ID_hecho', 'FECHA_y',
#        'AAAA_y', 'MM_y', 'DD_y', 'ROL', 'VICTIMA_y', 'SEXO', 'EDAD',
#        'FECHA_FALLECIMIENTO'],
#       dtype='object')

# %%
columnas_eliminar = ['N_VICTIMAS','FECHA_x','AAAA_x', 'MM_x','DD_x', 'Altura', 'Cruce', 'VICTIMA_x', 'ID_hecho', 'HORA', 'XY (CABA)','FECHA_FALLECIMIENTO', 'PARTICIPANTES', 'Calle', 'Dirección Normalizada']
merged_df=merged_df.drop(columns=columnas_eliminar)

# %%
merged_df
# Out:
#             ID  HH                            LUGAR_DEL_HECHO TIPO_DE_CALLE  \
# 0    2016-0001   4  AV PIEDRA BUENA Y AV FERNANDEZ DE LA CRUZ       AVENIDA
# 1    2016-0002   1          AV GRAL PAZ  Y AV DE LOS CORRALES      GRAL PAZ
# 2    2016-0003   7                         AV ENTRE RIOS 2034       AVENIDA
# 3    2016-0004   0      AV LARRAZABAL Y GRAL VILLEGAS CONRADO       AVENIDA
# 4    2016-0005   5  AV SAN JUAN Y PRESIDENTE LUIS SAENZ PEÑA        AVENIDA
# ..         ...  ..                                        ...           ...
# 712  2021-0093  17                          AV. RIESTRA Y MOM       AVENIDA
# 713  2021-0094   1                    AU DELLEPIANE Y LACARRA     AUTOPISTA
# 714  2021-0095   0                        AV. GAONA Y TERRADA       AVENIDA
# 715  2021-0096  10                         AV. EVA PERON 4071       AVENIDA
# 716  2021-0097   6                    PADRE CARLOS MUJICA 709         CALLE
#
# ...

# %%
merged_df.columns
# Out:
# Index(['ID', 'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'COMUNA', 'pos x',
#        'pos y', 'ACUSADO', 'FECHA_y', 'AAAA_y', 'MM_y', 'DD_y', 'ROL',
#        'VICTIMA_y', 'SEXO', 'EDAD'],
#       dtype='object')

# %%
merged_df["SEXO"].unique()
# Out:
# array(['MASCULINO', 'FEMENINO', 'SD'], dtype=object)

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <h3>Visualizaciones exploratorias<h3>

# %% [markdown]
# 1. Gráfico de barras para mostrar quiénes mueren más (por género):

# %%
merged_df['SEXO'].replace('SD', pd.NaT, inplace=True)
# Out:
# /tmp/ipykernel_4800/846482456.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['SEXO'].replace('SD', pd.NaT, inplace=True)

# %%
merged_df['SEXO'].isna().sum()
# Out:
# 6

# %% [markdown]
# Imputamos el valor de moda a los valores nulos

# %%
# Calcula el valor medio
sexo_moda = merged_df['SEXO'].mode()[0]

# Imputa el valor medio en los valores nulos
merged_df['SEXO'].fillna(sexo_moda, inplace=True)
# Out:
# /tmp/ipykernel_4800/1038200130.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['SEXO'].fillna(sexo_moda, inplace=True)

# %%
# Contar el número de muertes por género
muertes_por_genero = merged_df['SEXO'].value_counts(dropna=True)
# Crear el gráfico de pastel
plt.figure(figsize=(8, 8))
plt.pie(muertes_por_genero, labels=muertes_por_genero.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de VICTIMAS por Género')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# 2. Gráfico de barras para mostrar en qué mueren más (por tipo de vehículo o situación):

# %%
merged_df['VICTIMA_y'] = merged_df['VICTIMA_y'].replace('SD', 'MOTO')

# %%
# Contar el número de muertes por tipo de vehículo o situación
muertes_por_tipo = merged_df['VICTIMA_y'].value_counts()

# Crear el gráfico de barras
plt.bar(muertes_por_tipo.index, muertes_por_tipo.values)
plt.xlabel('Tipo de Vehículo o Situación')
plt.ylabel('Número de VICTIMAS')
plt.title('VICTIMAS por Tipo')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mayor legibilidad
plt.show()

# %% [markdown]
# 3. Gráfico de barras para mostrar dónde mueren más (por rol en el accidente):

# %%
merged_df['ROL'] = merged_df['ROL'].replace('SD', 'CONDUCTOR')

# %%
# Contar el número de muertes por rol en el accidente
muertes_por_rol = merged_df['ROL'].value_counts()

# Crear el gráfico de barras
plt.bar(muertes_por_rol.index, muertes_por_rol.values)
plt.xlabel('Rol en el Accidente')
plt.ylabel('Número de VICTIMAS')
plt.title('VICTIMAS por Rol en el Accidente')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mayor legibilidad
plt.show()

# %% [markdown]
# 4. Gráfico de barras para mostrar la distribución de la hora de los accidentes por sexo:

# %%
merged_df['HH'] = merged_df['HH'].replace('SD', 0)

# %%
merged_df['HH'] = merged_df['HH'].astype(int)

# %%
merged_df[merged_df['HH'] >= 11]
# Out:
#             ID  HH                                    LUGAR_DEL_HECHO  \
# 5    2016-0008  18                     AV 27 DE FEBRERO Y AV ESCALADA
# 6    2016-0009  19                       NOGOYA Y JOAQUIN V. GONZALES
# 7    2016-0010  15                AV GENERAL PAZ Y AV DE LOS CORRALES
# 9    2016-0013  11                                 AV ENTRE RIOS 1366
# 11   2016-0016  22  AV REGIMIENTO DE PATRICIOS Y QUINQUELA MARTIN ...
# ..         ...  ..                                                ...
# 706  2021-0087  11                                     ESMERALDA 1359
# 707  2021-0088  15                           AV. MOROE Y 3 DE FEBRERO
# 709  2021-0090  11                           AV. 9 DE JULIO Y LAVALLE
# 710  2021-0091  23                            BAIGORRIA Y VICTOR HUGO
# 712  2021-0093  17                                  AV. RIESTRA Y MOM
#
#     TIPO_DE_CALLE  COMUNA         pos x         pos y      ACUSADO  \
# ...

# %%
# Calcular el recuento de víctimas para cada hora
count_by_hour = merged_df['HH'].value_counts()

# Ordenar las horas según el recuento de víctimas y seleccionar las 5 horas con más víctimas
top_5_hours = count_by_hour.head(5)

# Filtrar el dataframe original para incluir solo las filas correspondientes a las 5 horas principales
merged_df_top_5_hours = merged_df[merged_df['HH'].isin(top_5_hours.index)]

# Crear el histograma con Seaborn y agregar el variable "SEXO" como "hue"
plt.figure(figsize=(10, 6))  # Tamaño del gráfico más grande
sns.histplot(data=merged_df_top_5_hours, x='HH', bins=5, hue='SEXO', palette="colorblind", edgecolor='black')

plt.xlabel('Hora del Accidente')
plt.ylabel('Número de Accidentes')
plt.title('Distribución de la Hora de los Accidentes (Top 5 Horas con Más Víctimas)')

# Eliminar guiones bajos al principio de las etiquetas de la leyenda
handles, labels = plt.gca().get_legend_handles_labels()
labels = [label.lstrip('_') for label in labels]
plt.legend(handles, labels, title='Sexo')

plt.show()

# %% [markdown]
# 5. Gráfico de barras para mostrar la distribución de la edad de las personas que se accidentan:

# %%
# Reemplazar los valores "SD" con NaN
merged_df['EDAD'].replace('SD', pd.NaT, inplace=True)
# Out:
# /tmp/ipykernel_4800/1403523870.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['EDAD'].replace('SD', pd.NaT, inplace=True)

# %%
# Filtrar las edades válidas (no nulas)
edades_validas = merged_df['EDAD'].dropna()

# Calcular la frecuencia de cada edad
frecuencia_edad = edades_validas.value_counts()

# Seleccionar las cinco edades con mayor frecuencia
top_5_edades = frecuencia_edad.head(5)

# Crear el gráfico de barras
plt.bar(top_5_edades.index, top_5_edades.values)
plt.xlabel('Edad')
plt.ylabel('Número de VICTIMAS')
plt.title('Top 5 Edades con Más VICTIMAS')
plt.show()

# %% [markdown]
# 6. Gráfico de densidad de distribución de edad de las víctimas:

# %%
# Rellenar los valores nulos con cero
merged_df['EDAD'] = merged_df['EDAD'].fillna(0)

# Convertir la columna de edad a tipo entero
merged_df['EDAD'] = merged_df['EDAD'].astype(int)

# %%
# Encontrar el valor más repetido excluyendo 0
value_counts = merged_df['EDAD'].value_counts()
most_common_value = value_counts[value_counts.index != 0].idxmax()

# Reemplazar 0 con el valor más repetido
merged_df['EDAD'] = merged_df['EDAD'].replace(0, most_common_value)

# %%
# Crear el gráfico de densidad de distribución de edad
merged_df['EDAD'].plot(kind='density')
plt.xlabel('Edad')
plt.ylabel('Densidad')
plt.title('Distribución de Edad de las Víctimas')
plt.show()

# %% [markdown]
# 7. Mapa de las coordenadas

# %%
merged_df.columns
# Out:
# Index(['ID', 'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'COMUNA', 'pos x',
#        'pos y', 'ACUSADO', 'FECHA_y', 'AAAA_y', 'MM_y', 'DD_y', 'ROL',
#        'VICTIMA_y', 'SEXO', 'EDAD'],
#       dtype='object')

# %%
import folium

merged_df['pos x'] = pd.to_numeric(merged_df['pos x'], errors='coerce')
merged_df['pos y'] = pd.to_numeric(merged_df['pos y'], errors='coerce')
merged_df_clean = merged_df.dropna(subset=['pos x', 'pos y'])

# Eliminar filas con valores NaN en las coordenadas
merged_df_clean = merged_df.dropna(subset=['pos x', 'pos y'])

# Crear un mapa centrado en las coordenadas promedio
mapa = folium.Map(location=[merged_df_clean['pos y'].mean(), merged_df_clean['pos x'].mean()], zoom_start=12)

# Añadir marcadores para cada accidente con la descripción del tipo de accidente
for index, row in merged_df_clean.iterrows():
    folium.Marker([row['pos y'], row['pos x']], popup=row['SEXO']).add_to(mapa)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Estadísticas descriptivas
descriptive_stats = merged_df.describe()
print(descriptive_stats)
# Out:
#                HH      COMUNA       pos x       pos y       AAAA_y  \
# count  717.000000  717.000000  704.000000  704.000000   717.000000
# mean    11.538354    7.430962  -58.441664  -34.619700  2018.174338
# std      6.709265    4.385067    0.046397    0.035292     1.672655
# min      0.000000    0.000000  -58.529942  -34.705250  2016.000000
# 25%      6.000000    4.000000  -58.476556  -34.643918  2017.000000
# 50%     11.000000    8.000000  -58.444513  -34.622866  2018.000000
# 75%     17.000000   11.000000  -58.401841  -34.597013  2019.000000
# max     23.000000   15.000000  -58.356082  -34.534654  2021.000000
#
#              MM_y        DD_y        EDAD
# count  717.000000  717.000000  717.000000
# mean     6.688982   15.960948   41.267782
# std      3.575140    8.683358   19.306213
# min      1.000000    1.000000    1.000000
# 25%      4.000000    9.000000   28.000000
# 50%      7.000000   16.000000   35.000000
# 75%     10.000000   23.000000   55.000000
# ...

# %% [markdown]
# Despues de algunas transformaciones y exploraciones procedemos a comprobar algunos valores nulos "SD"

# %%
merged_df.columns
# Out:
# Index(['ID', 'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'COMUNA', 'pos x',
#        'pos y', 'ACUSADO', 'FECHA_y', 'AAAA_y', 'MM_y', 'DD_y', 'ROL',
#        'VICTIMA_y', 'SEXO', 'EDAD'],
#       dtype='object')

# %%
merged_df['LUGAR_DEL_HECHO'].unique()
merged_df[merged_df['LUGAR_DEL_HECHO'] == 'SD']
# Out:
#             ID  HH LUGAR_DEL_HECHO TIPO_DE_CALLE  COMUNA  pos x  pos y  \
# 121  2016-0151  20              SD         CALLE       0    NaN    NaN
#
#     ACUSADO     FECHA_y  AAAA_y  MM_y  DD_y     ROL VICTIMA_y       SEXO  EDAD
# 121      SD  11/18/2016    2016    11    18  PEATON    PEATON  MASCULINO    30

# %%
moda = merged_df['LUGAR_DEL_HECHO'].mode()[0]
merged_df['LUGAR_DEL_HECHO'] = merged_df['LUGAR_DEL_HECHO'].replace('SD', moda)
print(merged_df['LUGAR_DEL_HECHO'].value_counts())
moda
# Out:
# LUGAR_DEL_HECHO
# AV 27 DE FEBRERO Y AV ESCALADA                                 5
# AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUCENA VILLAFLOR    3
# Paz, Gral. Av. 11200                                           2
# AV LA PLATA Y CNEL GREGORIO POMAR                              2
# Rivadavia Av. y Pedernera                                      2
#                                                               ..
# AU DELLEPIANE Y AV. ESCALADA                                   1
# ALBARIÑO Y AV. ARGENTINA                                       1
# JUAN RAMIREZ DE VELAZCO 1211                                   1
# AV. FERNANDEZ DE LA CRUZ Y LARRAYA                             1
# PADRE CARLOS MUJICA 709                                        1
# Name: count, Length: 682, dtype: int64
# 'AV 27 DE FEBRERO Y AV ESCALADA'

# %%
# Ejemplo de imputación con la media
merged_df['pos x'] = merged_df['pos x'].fillna(merged_df['pos x'].mean())

# Ejemplo de imputación con interpolación
merged_df['pos x'] = merged_df['pos x'].interpolate()

# %%
# Ejemplo de imputación con la media
merged_df['pos y'] = merged_df['pos y'].fillna(merged_df['pos y'].mean())

# Ejemplo de imputación con interpolación
merged_df['pos y'] = merged_df['pos y'].interpolate()

# %% [markdown]
# ACUSADO

# %%
merged_df['ACUSADO'].unique()
# Out:
# array(['AUTO', 'PASAJEROS', 'SD', 'OBJETO FIJO', 'CARGAS', 'MOTO',
#        'MULTIPLE', 'OTRO', 'BICICLETA', 'TREN'], dtype=object)

# %%
# Encontrar el valor más repetido excluyendo 'SD'
value_counts = merged_df['ACUSADO'].value_counts()
most_common_value = value_counts[value_counts.index != 'SD'].idxmax()

# Reemplazar 'SD' con el valor más repetido
merged_df['ACUSADO'] = merged_df['ACUSADO'].replace('SD', most_common_value)

# %%
# Contar los valores en la columna 'ACUSADO' después del reemplazo
value_counts = merged_df['ACUSADO'].value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Frecuencia de cada valor en la columna ACUSADO')
plt.xlabel('Tipo de Acusado')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Vitimas por tipo de calle

# %%
# Contar el número de muertes por tipo de vehículo o situación
tipo_calle = merged_df['TIPO_DE_CALLE'].value_counts()

# Crear el gráfico de barras
plt.bar(tipo_calle.index, tipo_calle.values)
plt.xlabel('Tipo de Calle o Lugar')
plt.ylabel('Número de Victimas')
plt.title('Victimas por tipo de calle')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mayor legibilidad
plt.show()

# %%
merged_df.isnull().sum()
# Out:
# ID                 0
# HH                 0
# LUGAR_DEL_HECHO    0
# TIPO_DE_CALLE      0
# COMUNA             0
# pos x              0
# pos y              0
# ACUSADO            0
# FECHA_y            0
# AAAA_y             0
# MM_y               0
# DD_y               0
# ROL                0
# VICTIMA_y          0
# SEXO               0
# EDAD               0
# dtype: int64

# %%
merged_df.to_csv("./data/Final.csv", index=False)

# %% [markdown]
# <h1>KPI´S</h1>

# %%
df = pd.read_csv('./data/Final.csv').reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['ID', 'HH', 'LUGAR_DEL_HECHO', 'TIPO_DE_CALLE', 'COMUNA', 'pos x',
#        'pos y', 'ACUSADO', 'FECHA_y', 'AAAA_y', 'MM_y', 'DD_y', 'ROL',
#        'VICTIMA_y', 'SEXO', 'EDAD'],
#       dtype='object')

# %% [markdown]
# <h2>KPI1</h2>

# %%
df['FECHA_y'] = pd.to_datetime(df['FECHA_y'])

# %%
def calcular_tasa_homicidios(df, poblacion):
    homicidios = df.shape[0]
    tasa = (homicidios / poblacion) * 100000
    return tasa

def filtrar_por_periodo(df, start_date, end_date):
    return df[(df['FECHA_y'] >= start_date) & (df['FECHA_y'] < end_date)]

# %%
end_date = df['FECHA_y'].max()
start_date_ultimo_semestre = end_date - pd.DateOffset(months=6)
start_date_semestre_anterior = start_date_ultimo_semestre - pd.DateOffset(months=6)
start_date_semestre_anterior
# Out:
# Timestamp('2020-12-30 00:00:00')

# %%
ultimo_semestre = filtrar_por_periodo(df, start_date_ultimo_semestre, end_date)
semestre_anterior = filtrar_por_periodo(df, start_date_semestre_anterior, start_date_ultimo_semestre)

# %%
poblacion_caba = 3000000
tasa_ultimo_semestre = calcular_tasa_homicidios(ultimo_semestre, poblacion_caba)
tasa_semestre_anterior = calcular_tasa_homicidios(semestre_anterior, poblacion_caba)

# %%
# Calcular la reducción necesaria (10% de la tasa actual)
tasa_reducida = tasa_ultimo_semestre * 0.90
tasa_reducida
# Out:
# 1.23

# %%
print(f"Tasa de homicidios en el último semestre: {tasa_ultimo_semestre}")
print(f"Tasa de homicidios en el semestre anterior: {tasa_semestre_anterior}")
print(f"Tasa objetivo (10% reducción): {tasa_reducida}")
# Out:
# Tasa de homicidios en el último semestre: 1.3666666666666667
# Tasa de homicidios en el semestre anterior: 1.8333333333333333
# Tasa objetivo (10% reducción): 1.23

# %% [markdown]
# <h2>KPI2</h2>

# %%
df_moto = df[df['VICTIMA_y'] == 'MOTO']
accidentes_por_ano = df_moto[df_moto['VICTIMA_y'].notnull()].groupby(df_moto['FECHA_y'].dt.year).size()

# %%
accidentes_a = accidentes_por_ano.get(2016, 0)
accidentes_b = accidentes_por_ano.get(2017, 0)

# %%
reduccion_accidentes_moto = ((accidentes_a - accidentes_b) / accidentes_a) * 100 if accidentes_a != 0 else 0

# %%
print(f"Accidentes mortales de motociclistas en 2016: {accidentes_b}")
print(f"Accidentes mortales de motociclistas en 2015: {accidentes_a}")
print(f"Reducción necesaria (7%): {reduccion_accidentes_moto}")
# Out:
# Accidentes mortales de motociclistas en 2016: 60
# Accidentes mortales de motociclistas en 2015: 70
# Reducción necesaria (7%): 14.285714285714285

# %% [markdown]
# <h2>KPI-Propuesto</h2>

# %% [markdown]
# Reducir en un 5% la tasa de accidentes con víctimas en avenidas en el último año en comparación con el año anterior

# %% [markdown]
# Se define como el número de accidentes con víctimas en avenidas por cada 100,000 habitantes en un área geográfica durante un período de tiempo específico. Su fórmula es:

# %%
# Filtrar los datos para obtener solo los accidentes en avenidas
df_avenidas = df[df['TIPO_DE_CALLE'] == 'AVENIDA']

# %%
def calcular_tasa_accidentes_victimas(df, poblacion):
    accidentes = df[df['VICTIMA_y'].notnull()].shape[0]
    tasa = (accidentes / poblacion) * 100000
    return tasa

# %%
accidentes_avenidas_por_ano = df_avenidas[df_avenidas['VICTIMA_y'].notnull()].groupby(df_avenidas['FECHA_y'].dt.year).size()
accidentes_avenidas_por_ano
# Out:
# FECHA_y
# 2016    91
# 2017    81
# 2018    93
# 2019    64
# 2020    52
# 2021    61
# dtype: int64

# %%
ultimo_ano = accidentes_avenidas_por_ano.get(2021, 0)
penultimo_ano = accidentes_avenidas_por_ano.get(2020, 0)
ultimo_ano
# Out:
# 61

# %%
tasa_accidentes_ultimo_ano = (ultimo_ano / poblacion_caba) * 100000
tasa_accidentes_penultimo_ano = (penultimo_ano / poblacion_caba) * 100000

# %%
reduccion_necesaria = tasa_accidentes_ultimo_ano * 0.95

# %%
tasa = tasa_accidentes_ultimo_ano - tasa_accidentes_penultimo_ano
tasa
# Out:
# 0.30000000000000004

# %%
print(f"Tasa de accidentes con víctimas en avenidas en el último año: {tasa_accidentes_ultimo_ano}")
print(f"Tasa de accidentes con víctimas en avenidas en el año anterior: {tasa_accidentes_penultimo_ano}")
print(f"Tasa objetivo (5% reducción): {reduccion_necesaria}")
print(f"Accidentes con víctimas en avenidas en el último año: {ultimo_ano}")
print(f"Accidentes con víctimas en avenidas en el año anterior: {penultimo_ano}")
# Out:
# Tasa de accidentes con víctimas en avenidas en el último año: 2.033333333333333
# Tasa de accidentes con víctimas en avenidas en el año anterior: 1.7333333333333332
# Tasa objetivo (5% reducción): 1.9316666666666664
# Accidentes con víctimas en avenidas en el último año: 61
# Accidentes con víctimas en avenidas en el año anterior: 52

# %%
reduccion_lograda = ((tasa_accidentes_penultimo_ano - tasa_accidentes_ultimo_ano) / tasa_accidentes_penultimo_ano) * 100
reduccion_lograda
# Out:
# -17.307692307692314
